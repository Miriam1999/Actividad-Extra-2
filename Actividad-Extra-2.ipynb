# %% [markdown]
# Para este proyecto, decidí utilizar la misma **actividad 2** sobre *optimización de SymPy* que se nos dejó de tarea hace aproximadamente una semana. Me creé mi cuenta de Github y de hecho lo he estado utilizando como nube para subir todas las tareas que se nos han asignado. También ya hice un fork del contenido de la clase desde la cuenta del profesor Dmitri-XII y lo cloné a mi cuenta para poder acceder más fácilmente. Entre los comandos que he utilizado en github está el de cambiarle el nombre a un repositorio, subir archivos (específicamente notebooks) a los mismos, le he puesto descripción a cada repositorio, y pongo nombres muy descriptivos a los commits cada vez que subo un archivo actualizado. En la actividad 2, por ejemplo, el primer notebook que subí sólo tenía las primeras dos funciones y al commit le llamé "Primeras dos funciones" mientras que al tercero que subí, ya terminado, le llamé "Documento terminado". También he eliminado algunos repositorios. Finalmente, pulí mi perfil al agregarle foto, descripción y demás cosas y exploré mi calendario de contribuciones. Hasta ahora llevo 31.

# %% [markdown]
# ![Commit%20de%20Documento%20Terminado.PNG](attachment:Commit%20de%20Documento%20Terminado.PNG)

# %% [markdown]
# ![Mis%20repositorios.PNG](attachment:Mis%20repositorios.PNG)

# %% [markdown]
# ![Perfil%20de%20Github.PNG](attachment:Perfil%20de%20Github.PNG)
